# %% [markdown]
# ## Time Series EDA

# %%
## Install Pandas Data Reader
# !pip install pandas-datareader

# %%
import pandas_datareader as pdr
import pandas as pd
from datetime import datetime

# %%
import yfinance as yf

# Fetch Tesla stock data
df_tesla = yf.download('TSLA', start='2020-01-01', end='2021-09-01')

# Display the first few rows
df_tesla.head()
# Out:
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  1 of 1 completed
# Price           Close       High        Low       Open     Volume
# Ticker           TSLA       TSLA       TSLA       TSLA       TSLA
# Date
# 2020-01-02  28.684000  28.713333  28.114000  28.299999  142981500
# 2020-01-03  29.534000  30.266666  29.128000  29.366667  266677500
# 2020-01-06  30.102667  30.104000  29.333332  29.364668  151995000
# 2020-01-07  31.270666  31.441999  30.224001  30.760000  268231500
# 2020-01-08  32.809334  33.232666  31.215334  31.580000  467164500

# %%
df_tesla.tail()
# Out:
# Price            Close        High         Low        Open    Volume
# Ticker            TSLA        TSLA        TSLA        TSLA      TSLA
# Date
# 2021-08-25  237.066666  238.990005  234.666672  235.676666  37936800
# 2021-08-26  233.720001  238.466660  232.539993  236.103333  39642900
# 2021-08-27  237.306671  238.333328  234.033340  235.000000  41501400
# 2021-08-30  243.636673  243.666672  237.576660  238.240005  55812600
# 2021-08-31  245.240005  246.796661  242.146667  244.333328  62566200

# %%
df_tesla['High'].plot(figsize=(12,4))
# Out:
# <Axes: xlabel='Date'>

# %%
## xlimit and y limit
df_tesla['High'].plot(xlim=['2020-01-01','2021-09-01'],figsize=(12,4))
# Out:
# <Axes: xlabel='Date'>

# %%
## xlimit and y limit
df_tesla['High'].plot(xlim=['2020-01-01','2021-09-01'],ylim=[0,900],figsize=(12,4))
# Out:
# <Axes: xlabel='Date'>

# %%
import matplotlib.pyplot as plt

# Plot Tesla's 'High' prices with specified limits and styling
df_tesla['High'].plot(
    xlim=('2020-01-01', '2021-09-01'),  # Set x-axis limits
    ylim=(0, 900),  # Set y-axis limits
    figsize=(12, 4),  # Set figure size
    linestyle='--',  # Dashed line style
    color='green',  # Line color
    title="Tesla Stock High Prices (2020-2021)"  # Add title for clarity
)

plt.xlabel('Date')
plt.ylabel('Stock Price (USD)')
plt.grid(True)  # Optional: Adds grid for better readability
plt.show()

# %%
df_tesla.index
# Out:
# DatetimeIndex(['2020-01-02', '2020-01-03', '2020-01-06', '2020-01-07',
#                '2020-01-08', '2020-01-09', '2020-01-10', '2020-01-13',
#                '2020-01-14', '2020-01-15',
#                ...
#                '2021-08-18', '2021-08-19', '2021-08-20', '2021-08-23',
#                '2021-08-24', '2021-08-25', '2021-08-26', '2021-08-27',
#                '2021-08-30', '2021-08-31'],
#               dtype='datetime64[ns]', name='Date', length=420, freq=None)

# %%
# Extract the index (dates) from the DataFrame for the given date range
index = df_tesla.loc['2020-01-01':'2021-09-01'].index

# Extract the 'Open' column values for the same date range
share_open = df_tesla.loc['2020-01-01':'2021-09-01']['Open']

# %%
share_open
# Out:
# Ticker            TSLA
# Date
# 2020-01-02   28.299999
# 2020-01-03   29.366667
# 2020-01-06   29.364668
# 2020-01-07   30.760000
# 2020-01-08   31.580000
# ...                ...
# 2021-08-25  235.676666
# 2021-08-26  236.103333
# 2021-08-27  235.000000
# 2021-08-30  238.240005
# 2021-08-31  244.333328
#
# [420 rows x 1 columns]

# %%
index
# Out:
# DatetimeIndex(['2020-01-02', '2020-01-03', '2020-01-06', '2020-01-07',
#                '2020-01-08', '2020-01-09', '2020-01-10', '2020-01-13',
#                '2020-01-14', '2020-01-15',
#                ...
#                '2021-08-18', '2021-08-19', '2021-08-20', '2021-08-23',
#                '2021-08-24', '2021-08-25', '2021-08-26', '2021-08-27',
#                '2021-08-30', '2021-08-31'],
#               dtype='datetime64[ns]', name='Date', length=420, freq=None)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
figure,axis=plt.subplots()
plt.tight_layout()
## Preventing overlapping
figure.autofmt_xdate()
axis.plot(index,share_open)

# %%
## Datetime Index

# %%
df_tesla=df_tesla.reset_index()

# %%
df_tesla.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 420 entries, 0 to 419
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   (Date, )        420 non-null    datetime64[ns]
#  1   (Close, TSLA)   420 non-null    float64
#  2   (High, TSLA)    420 non-null    float64
#  3   (Low, TSLA)     420 non-null    float64
#  4   (Open, TSLA)    420 non-null    float64
#  5   (Volume, TSLA)  420 non-null    int64
# dtypes: datetime64[ns](1), float64(4), int64(1)
# memory usage: 19.8 KB

# %%
df_tesla=df_tesla.set_index('Date',drop=True)

# %%
df_tesla.head()
# Out:
# Price           Close       High        Low       Open     Volume
# Ticker           TSLA       TSLA       TSLA       TSLA       TSLA
# Date
# 2020-01-02  28.684000  28.713333  28.114000  28.299999  142981500
# 2020-01-03  29.534000  30.266666  29.128000  29.366667  266677500
# 2020-01-06  30.102667  30.104000  29.333332  29.364668  151995000
# 2020-01-07  31.270666  31.441999  30.224001  30.760000  268231500
# 2020-01-08  32.809334  33.232666  31.215334  31.580000  467164500

# %%
## datetime
from datetime import datetime

# %%
datetime(2021,11,21)
# Out:
# datetime.datetime(2021, 11, 21, 0, 0)

# %%
datetime.now()
# Out:
# datetime.datetime(2025, 4, 1, 14, 18, 7, 914782)

# %%
date=datetime(2021,11,21)

# %%
date
# Out:
# datetime.datetime(2021, 11, 21, 0, 0)

# %%
date.date()
# Out:
# datetime.date(2021, 11, 21)

# %%
date.day
# Out:
# 21

# %%
date.weekday()
# Out:
# 6

# %%
date.year
# Out:
# 2021

# %%
date.month
# Out:
# 11

# %% [markdown]
# ## Time Resampling

# %%
df_tesla.head()
# Out:
# Price           Close       High        Low       Open     Volume
# Ticker           TSLA       TSLA       TSLA       TSLA       TSLA
# Date
# 2020-01-02  28.684000  28.713333  28.114000  28.299999  142981500
# 2020-01-03  29.534000  30.266666  29.128000  29.366667  266677500
# 2020-01-06  30.102667  30.104000  29.333332  29.364668  151995000
# 2020-01-07  31.270666  31.441999  30.224001  30.760000  268231500
# 2020-01-08  32.809334  33.232666  31.215334  31.580000  467164500

# %%
df_tesla.resample(rule='A').min()
# Out:
# <ipython-input-31-6c39fe627685>:1: FutureWarning: 'A' is deprecated and will be removed in a future version, please use 'YE' instead.
#   df_tesla.resample(rule='A').min()
# Price            Close        High         Low        Open    Volume
# Ticker            TSLA        TSLA        TSLA        TSLA      TSLA
# Date
# 2020-12-31   24.081333   26.990667   23.367332   24.980000  52073100
# 2021-12-31  187.666672  188.736664  179.830002  184.183334  29401800

# %%
df_tesla.resample(rule='A').max()
# Out:
# <ipython-input-32-ad291441f546>:1: FutureWarning: 'A' is deprecated and will be removed in a future version, please use 'YE' instead.
#   df_tesla.resample(rule='A').max()
# Price            Close        High         Low        Open     Volume
# Ticker            TSLA        TSLA        TSLA        TSLA       TSLA
# Date
# 2020-12-31  235.223328  239.573334  230.373337  233.330002  914082000
# 2021-12-31  294.363342  300.133331  290.533325  297.126678  268189500

# %%
##year end frequency
df_tesla.resample(rule='A').max()['Open'].plot()
# Out:
# <ipython-input-33-64e059f60d14>:2: FutureWarning: 'A' is deprecated and will be removed in a future version, please use 'YE' instead.
#   df_tesla.resample(rule='A').max()['Open'].plot()
# <Axes: xlabel='Date'>

# %%
##quaterly start frequency
##https://towardsdatascience.com/resample-function-of-pandas-79b17ec82a78
df_tesla.resample(rule='QS').max()['High'].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
##Business End Frequency
##https://towardsdatascience.com/resample-function-of-pandas-79b17ec82a78
df_tesla.resample(rule='BA').max()
# Out:
# <ipython-input-35-58d030c56ff4>:3: FutureWarning: 'BA' is deprecated and will be removed in a future version, please use 'BYE' instead.
#   df_tesla.resample(rule='BA').max()
# Price            Close        High         Low        Open     Volume
# Ticker            TSLA        TSLA        TSLA        TSLA       TSLA
# Date
# 2020-12-31  235.223328  239.573334  230.373337  233.330002  914082000
# 2021-12-31  294.363342  300.133331  290.533325  297.126678  268189500

# %%
df_tesla.resample(rule='BQS').max()
# Out:
# Price            Close        High         Low        Open     Volume
# Ticker            TSLA        TSLA        TSLA        TSLA       TSLA
# Date
# 2020-01-01   61.161331   64.599335   60.068001   61.566666  914082000
# 2020-04-01   71.987335   72.512665   66.915337   67.518669  487977000
# 2020-07-01  166.106674  167.496674  156.836670  167.380005  584781000
# 2020-10-01  235.223328  239.573334  230.373337  233.330002  666378600
# 2021-01-01  294.363342  300.133331  290.533325  297.126678  268189500
# 2021-04-01  254.106674  260.263336  244.203339  256.899994  147052200
# 2021-07-01  245.240005  246.796661  242.146667  244.333328  100847400

# %%
##plotting
df_tesla['Open'].resample(rule='A').mean().plot(kind='bar')
# Out:
# <ipython-input-37-edfbddaa0627>:2: FutureWarning: 'A' is deprecated and will be removed in a future version, please use 'YE' instead.
#   df_tesla['Open'].resample(rule='A').mean().plot(kind='bar')
# <Axes: xlabel='Date'>

# %%
df_tesla['Open'].resample(rule='M').max().plot(kind='bar',figsize=(15,6))
# Out:
# <ipython-input-38-6ccccfdfc8e0>:1: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df_tesla['Open'].resample(rule='M').max().plot(kind='bar',figsize=(15,6))
# <Axes: xlabel='Date'>

# %%
df_tesla['High'].rolling(11).max().head(20)
# Out:
# Ticker           TSLA
# Date
# 2020-01-02        NaN
# 2020-01-03        NaN
# 2020-01-06        NaN
# 2020-01-07        NaN
# 2020-01-08        NaN
# 2020-01-09        NaN
# 2020-01-10        NaN
# 2020-01-13        NaN
# 2020-01-14        NaN
# 2020-01-15        NaN
# 2020-01-16  36.493999
# 2020-01-17  36.493999
# 2020-01-21  36.571999
# 2020-01-22  39.633331
# 2020-01-23  39.633331
# 2020-01-24  39.633331
# 2020-01-27  39.633331
# 2020-01-28  39.633331
# 2020-01-29  39.633331
# 2020-01-30  43.391998

# %%
df_tesla.head()
# Out:
# Price           Close       High        Low       Open     Volume
# Ticker           TSLA       TSLA       TSLA       TSLA       TSLA
# Date
# 2020-01-02  28.684000  28.713333  28.114000  28.299999  142981500
# 2020-01-03  29.534000  30.266666  29.128000  29.366667  266677500
# 2020-01-06  30.102667  30.104000  29.333332  29.364668  151995000
# 2020-01-07  31.270666  31.441999  30.224001  30.760000  268231500
# 2020-01-08  32.809334  33.232666  31.215334  31.580000  467164500

# %%
df_tesla['Open:30 days rolling']=df_tesla['Open'].rolling(30).mean()

# %%
df_tesla.head(31)
# Out:
# Price           Close       High        Low       Open     Volume  \
# Ticker           TSLA       TSLA       TSLA       TSLA       TSLA
# Date
# 2020-01-02  28.684000  28.713333  28.114000  28.299999  142981500
# 2020-01-03  29.534000  30.266666  29.128000  29.366667  266677500
# 2020-01-06  30.102667  30.104000  29.333332  29.364668  151995000
# 2020-01-07  31.270666  31.441999  30.224001  30.760000  268231500
# 2020-01-08  32.809334  33.232666  31.215334  31.580000  467164500
# 2020-01-09  32.089333  33.253334  31.524668  33.139999  426606000
# 2020-01-10  31.876667  32.329334  31.580000  32.119331  194392500
# 2020-01-13  34.990665  35.042000  32.799999  32.900002  397764000
# 2020-01-14  35.861332  36.493999  34.993332  36.284000  434943000
# 2020-01-15  34.566666  35.855999  34.452667  35.317333  260532000
# 2020-01-16  34.232666  34.297333  32.811333  32.916668  326050500
# 2020-01-17  34.033333  34.377998  33.543999  33.840668  204436500
# ...

# %%
df_tesla[['Open','Open:30 days rolling']].plot(figsize=(12,5))
# Out:
# <Axes: xlabel='Date'>
